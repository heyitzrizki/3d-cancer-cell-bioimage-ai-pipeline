# %% [markdown]
# # 0.1 Import Libraries

# %%
from pathlib import Path

# %% [markdown]
# # 0.2 Set Paths

# %%
DATA_ROOT = Path("/content/drive/MyDrive/self learning/Self Project/3d-cancer-cell-bioimage-ai-pipeline-data")
DATASET_DIR = DATA_ROOT / "raw" / "Fluo-C3DL-MDA231"

# %% [markdown]
# # 1.1 Load Dataset
#
# Load the primary MDA231 dataset after completing the setup notebook.

# %% [markdown]
# # 1.2 Inspect Dataset Structure
#
# Validate CTC sequences and available annotations.

# %% [markdown]
# # 1.3 Visualize Sample Image
#
# Inspect representative slices before running the MVP.

# %% [markdown]
# # 2.1 Preprocessing Plan
#
# Load preprocessing parameters from `configs/mda231_mvp.yaml`.

# %% [markdown]
# # 3.1 Baseline Segmentation Plan
#
# Run and evaluate the classical baseline once exploration is complete.

# %% [markdown]
# # 4.1 Next Steps
#
# Persist predictions, metrics, and features under `DATA_ROOT`.
