# %% [markdown]
# # 1. Mount Google Drive

# %%
from google.colab import drive

drive.mount("/content/drive")

# %% [markdown]
# # 2. Clone GitHub Repository
#
# Replace `YOUR_USERNAME` after creating the GitHub repository.

# %%
REPO_URL = "https://github.com/YOUR_USERNAME/3d-cancer-cell-bioimage-ai-pipeline.git"
REPO_DIR = "/content/3d-cancer-cell-bioimage-ai-pipeline"
# !git clone "$REPO_URL" "$REPO_DIR"
# %cd "$REPO_DIR"

# %% [markdown]
# # 3. Install Requirements

# %%
# %pip install -q -r requirements.txt

# %% [markdown]
# # 4. Set DATA_ROOT Path

# %%
from pathlib import Path

DATA_ROOT = Path("/content/drive/MyDrive/self learning/Self Project/3d-cancer-cell-bioimage-ai-pipeline-data")
MDA231_DIR = DATA_ROOT / "raw" / "Fluo-C3DL-MDA231"
print(DATA_ROOT)

# %% [markdown]
# # 5. Create Drive Directories

# %%
# !python scripts/setup_drive_dirs.py --data-root "$DATA_ROOT"

# %% [markdown]
# # 6. Inspect Dataset

# %%
if MDA231_DIR.is_dir():
    # !python scripts/inspect_dataset.py --dataset-dir "$MDA231_DIR"
else:
    print(f"Dataset not found yet: {MDA231_DIR}")
